# %%
#DS360withAkanksha | Monday Special:Web Scraping

# %%
#Importing required packages

from bs4 import BeautifulSoup as bs4 #WebScraping Module
import requests #To get the content from URL
import pandas as pd #For Dataframe

# %%
# Printing URLs of 
pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1):
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
    print(pages)
    
    #http://books.toscrape.com/catalogue/page-1.html
# Out:
# ['http://books.toscrape.com/catalogue/page-1.html']
# ['http://books.toscrape.com/catalogue/page-1.html', 'http://books.toscrape.com/catalogue/page-2.html']
# ['http://books.toscrape.com/catalogue/page-1.html', 'http://books.toscrape.com/catalogue/page-2.html', 'http://books.toscrape.com/catalogue/page-3.html']
# ['http://books.toscrape.com/catalogue/page-1.html', 'http://books.toscrape.com/catalogue/page-2.html', 'http://books.toscrape.com/catalogue/page-3.html', 'http://books.toscrape.com/catalogue/page-4.html']
# ['http://books.toscrape.com/catalogue/page-1.html', 'http://books.toscrape.com/catalogue/page-2.html', 'http://books.toscrape.com/catalogue/page-3.html', 'http://books.toscrape.com/catalogue/page-4.html', 'http://books.toscrape.com/catalogue/page-5.html']

# %%
# Getting data and parsing data

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1):
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages:
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:30" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Getting data, parsing data and using 'prettify' function for indentation

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    print(soup.prettify()) #Using 'prettify' function for indentation
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:30" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Getting titles of the book

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    for i in soup.findAll('h3'):
        ttl=i.getText()
       # titles.append(ttl)
        print(ttl)
# Out:
# A Light in the ...
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History ...
# The Requiem Red
# The Dirty Little Secrets ...
# The Coming Woman: A ...
# The Boys in the ...
# The Black Maria
# Starving Hearts (Triangular Trade ...
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little ...
# Rip it Up and ...
# Our Band Could Be ...
# Olio
# Mesaerion: The Best Science ...
# Libertarianism for Beginners
# It's Only the Himalayas
# In Her Wake
# How Music Works
# Foolproof Preserving: A Guide ...
# Chase Me (Paris Nights ...
# Black Dust
# Birdsong: A Story in ...
# America's Cradle of Quarterbacks: ...
# Aladdin and His Wonderful ...
# Worlds Elsewhere: Journeys Around ...
# Wall and Piece
# The Four Agreements: A ...
# The Five Love Languages: ...
# The Elephant Tree
# The Bear and the ...
# Sophie's World
# Penny Maybe
# Maude (1883-1993):She Grew Up ...
# In a Dark, Dark ...
# Behind Closed Doors
# You can't bury them ...
# ...

# %%
# Getting titles of the book

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    print(soup.prettify()) #Using 'prettify' function for indentation
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:30" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Getting prices using p tags

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    #print(soup.prettify()) #Using 'prettify' function for indentation
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
    for j in soup.findAll('p', class_='price_color'):
        price=j.getText()
        prices.append(price)
    print(prices)
# Out:
# ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23', 'Â£22.65', 'Â£33.34', 'Â£17.93', 'Â£22.60', 'Â£52.15', 'Â£13.99', 'Â£20.66', 'Â£17.46', 'Â£52.29', 'Â£35.02', 'Â£57.25', 'Â£23.88', 'Â£37.59', 'Â£51.33', 'Â£45.17']
# ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23', 'Â£22.65', 'Â£33.34', 'Â£17.93', 'Â£22.60', 'Â£52.15', 'Â£13.99', 'Â£20.66', 'Â£17.46', 'Â£52.29', 'Â£35.02', 'Â£57.25', 'Â£23.88', 'Â£37.59', 'Â£51.33', 'Â£45.17', 'Â£12.84', 'Â£37.32', 'Â£30.52', 'Â£25.27', 'Â£34.53', 'Â£54.64', 'Â£22.50', 'Â£53.13', 'Â£40.30', 'Â£44.18', 'Â£17.66', 'Â£31.05', 'Â£23.82', 'Â£36.89', 'Â£15.94', 'Â£33.29', 'Â£18.02', 'Â£19.63', 'Â£52.22', 'Â£33.63']
# ...

# %%
#Building dictionary

data={'Title': titles, 'Prices' : prices}
data
# Out:
# {'Title': ['A Light in the ...',
#   'Tipping the Velvet',
#   'Soumission',
#   'Sharp Objects',
#   'Sapiens: A Brief History ...',
#   'The Requiem Red',
#   'The Dirty Little Secrets ...',
#   'The Coming Woman: A ...',
#   'The Boys in the ...',
#   'The Black Maria',
#   'Starving Hearts (Triangular Trade ...',
#   "Shakespeare's Sonnets",
#   'Set Me Free',
#   "Scott Pilgrim's Precious Little ...",
#   'Rip it Up and ...',
#   'Our Band Could Be ...',
#   'Olio',
#   'Mesaerion: The Best Science ...',
#   'Libertarianism for Beginners',
#   "It's Only the Himalayas",
#   'In Her Wake',
#   'How Music Works',
#   'Foolproof Preserving: A Guide ...',
#   'Chase Me (Paris Nights ...',
#   'Black Dust',
#   'Birdsong: A Story in ...',
#   "America's Cradle of Quarterbacks: ...",
#   'Aladdin and His Wonderful ...',
#   'Worlds Elsewhere: Journeys Around ...',
#   'Wall and Piece',
#   'The Four Agreements: A ...',
#   'The Five Love Languages: ...',
#   'The Elephant Tree',
# ...

# %%
# Looking for tags for star ratings

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    print(soup.prettify()) #Using 'prettify' function for indentation
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
    for j in soup.findAll('p', class_='price_color'):
        price=j.getText()
        prices.append(price)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:30" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Looking for tags for star ratings

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    #print(soup.prettify()) #Using 'prettify' function for indentation
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
    for j in soup.findAll('p', class_='price_color'):
        price=j.getText()
        prices.append(price)
    for s in soup.findAll('p', class_='star-rating'):
        for k,v in s.attrs.items():
            print(k,v) #get class star rating
        #star =v[1]
        #stars.append(star)
# Out:
# class ['star-rating', 'Three']
# class ['star-rating', 'One']
# class ['star-rating', 'One']
# class ['star-rating', 'Four']
# class ['star-rating', 'Five']
# class ['star-rating', 'One']
# class ['star-rating', 'Four']
# class ['star-rating', 'Three']
# class ['star-rating', 'Four']
# class ['star-rating', 'One']
# class ['star-rating', 'Two']
# class ['star-rating', 'Four']
# class ['star-rating', 'Five']
# class ['star-rating', 'Five']
# class ['star-rating', 'Five']
# class ['star-rating', 'Three']
# class ['star-rating', 'One']
# class ['star-rating', 'One']
# class ['star-rating', 'Two']
# class ['star-rating', 'Two']
# class ['star-rating', 'One']
# class ['star-rating', 'Two']
# class ['star-rating', 'Three']
# class ['star-rating', 'Five']
# class ['star-rating', 'Five']
# class ['star-rating', 'Three']
# class ['star-rating', 'Three']
# class ['star-rating', 'Three']
# class ['star-rating', 'Five']
# class ['star-rating', 'Four']
# class ['star-rating', 'Five']
# ...

# %%
# Getting star ratings

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    #print(soup.prettify()) #Using 'prettify' function for indentation
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
    for j in soup.findAll('p', class_='price_color'):
        price=j.getText()
        prices.append(price)
    for s in soup.findAll('p', class_='star-rating'):
        for k,v in s.attrs.items():
            star =v[1]
            stars.append(star)
            print(star)
# Out:
# Three
# One
# One
# Four
# Five
# One
# Four
# Three
# Four
# One
# Two
# Four
# Five
# Five
# Five
# Three
# One
# One
# Two
# Two
# One
# Two
# Three
# Five
# Five
# Three
# Three
# Three
# Five
# Four
# Five
# Three
# Five
# One
# Five
# Three
# Two
# One
# Four
# Two
# Three
# Two
# Five
# Five
# Two
# One
# Five
# Four
# Four
# Three
# One
# One
# Three
# Four
# Five
# One
# One
# One
# Four
# Three
# Four
# Three
# Four
# Four
# Three
# Five
# One
# One
# Four
# Three
# Three
# One
# Five
# Four
# Two
# Two
# Three
# Two
# Two
# Three
# Five
# Five
# One
# Two
# Three
# Four
# One
# One
# Three
# Two
# Two
# Two
# Four
# Two
# Three
# Two
# One
# Two
# Five
# Four

# %%
#Updating the dictionary library

data={'Title': titles, 'Prices' : prices, 'Stars' : stars}
data
# Out:
# {'Title': ['A Light in the ...',
#   'Tipping the Velvet',
#   'Soumission',
#   'Sharp Objects',
#   'Sapiens: A Brief History ...',
#   'The Requiem Red',
#   'The Dirty Little Secrets ...',
#   'The Coming Woman: A ...',
#   'The Boys in the ...',
#   'The Black Maria',
#   'Starving Hearts (Triangular Trade ...',
#   "Shakespeare's Sonnets",
#   'Set Me Free',
#   "Scott Pilgrim's Precious Little ...",
#   'Rip it Up and ...',
#   'Our Band Could Be ...',
#   'Olio',
#   'Mesaerion: The Best Science ...',
#   'Libertarianism for Beginners',
#   "It's Only the Himalayas",
#   'In Her Wake',
#   'How Music Works',
#   'Foolproof Preserving: A Guide ...',
#   'Chase Me (Paris Nights ...',
#   'Black Dust',
#   'Birdsong: A Story in ...',
#   "America's Cradle of Quarterbacks: ...",
#   'Aladdin and His Wonderful ...',
#   'Worlds Elsewhere: Journeys Around ...',
#   'Wall and Piece',
#   'The Four Agreements: A ...',
#   'The Five Love Languages: ...',
#   'The Elephant Tree',
# ...

# %%
# Checking where are the URLs

pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    print(soup.prettify()) #Using 'prettify' function for indentation
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:30" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Getting book's image URLs
pages=[]
prices=[]
stars=[]
titles=[]
urlss=[]

pages_to_scrape=5

for i in range(1,pages_to_scrape+1): #Getting the data
    url = ('http://books.toscrape.com/catalogue/page-{}.html').format(i)
    pages.append(url)
for item in pages: #Parsing the data
    page =requests.get(item)
    soup = bs4(page.text, 'html.parser')
    #print(soup.prettify()) #Using 'prettify' function for indentation
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
    for j in soup.findAll('p', class_='price_color'):
        price=j.getText()
        prices.append(price)
    for s in soup.findAll('p', class_='star-rating'):
        for k,v in s.attrs.items():
            star =v[1]
            stars.append(star)
    divs =soup.findAll('div', class_='image_container')
    divs =soup.findAll('div', class_='image_container')
    for thumbs in divs:
        tgs=thumbs.find('img',class_='thumbnail')
        urls='http://books.toscrape.com/'+str(tgs['src'])
        newurls=urls.replace("../","")
        urlss.append(newurls)
        print(newurls)
# Out:
# http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg
# http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg
# http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg
# http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg
# http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg
# http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg
# http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg
# http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg
# http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg
# http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg
# http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg
# http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg
# ...

# %%
#Updating the dictionary

data={'Title': titles, 'Prices' : prices, 'Stars' : stars, 'URLs' : urlss}
data
# Out:
# {'Title': ['A Light in the ...',
#   'Tipping the Velvet',
#   'Soumission',
#   'Sharp Objects',
#   'Sapiens: A Brief History ...',
#   'The Requiem Red',
#   'The Dirty Little Secrets ...',
#   'The Coming Woman: A ...',
#   'The Boys in the ...',
#   'The Black Maria',
#   'Starving Hearts (Triangular Trade ...',
#   "Shakespeare's Sonnets",
#   'Set Me Free',
#   "Scott Pilgrim's Precious Little ...",
#   'Rip it Up and ...',
#   'Our Band Could Be ...',
#   'Olio',
#   'Mesaerion: The Best Science ...',
#   'Libertarianism for Beginners',
#   "It's Only the Himalayas",
#   'In Her Wake',
#   'How Music Works',
#   'Foolproof Preserving: A Guide ...',
#   'Chase Me (Paris Nights ...',
#   'Black Dust',
#   'Birdsong: A Story in ...',
#   "America's Cradle of Quarterbacks: ...",
#   'Aladdin and His Wonderful ...',
#   'Worlds Elsewhere: Journeys Around ...',
#   'Wall and Piece',
#   'The Four Agreements: A ...',
#   'The Five Love Languages: ...',
#   'The Elephant Tree',
# ...

# %%
# Putting the created dictionary into a dataframe

df=pd.DataFrame(data=data)

df.index+=1 #To start the index number from 1

df
# Out:
#                                   Title   Prices  Stars  \
# 1                    A Light in the ...  Â£51.77  Three
# 2                    Tipping the Velvet  Â£53.74    One
# 3                            Soumission  Â£50.10    One
# 4                         Sharp Objects  Â£47.82   Four
# 5          Sapiens: A Brief History ...  Â£54.23   Five
# ..                                  ...      ...    ...
# 96            Lumberjanes Vol. 3: A ...  Â£19.92    Two
# 97   Layered: Baking, Building, and ...  Â£40.11    One
# 98             Judo: Seven Steps to ...  Â£53.90    Two
# 99                                 Join  Â£35.67   Five
# 100               In the Country We ...  Â£22.00   Four
#
#                                                   URLs
# 1    http://books.toscrape.com/media/cache/2c/da/2c...
# 2    http://books.toscrape.com/media/cache/26/0c/26...
# 3    http://books.toscrape.com/media/cache/3e/ef/3e...
# 4    http://books.toscrape.com/media/cache/32/51/32...
# ...

# %%
#Exporting into an excel file

df.to_excel("C:/Users/akank/Desktop/bookstore.xlsx")
